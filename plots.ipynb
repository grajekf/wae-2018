# %%
import pandas as pd
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
df_low = pd.read_csv("results/kawa_mr/kawa_mr0.001_4.csv")
df_high = pd.read_csv("results/kawa_mr/kawa_mr0.3_3.csv")

# %%
plt.xlabel("Liczba ewaluacji funkcji celu")
plt.ylabel("Wartość funkcji celu najlepszego osobnika")
plt.plot(df_low["Fitness function uses"], df_low["Best fitness"])
plt.savefig("mr_low.png", dpi=360)

# %%
plt.xlabel("Liczba ewaluacji funkcji celu")
plt.ylabel("Wartość funkcji celu najlepszego osobnika")
plt.plot(df_high["Fitness function uses"], df_high["Best fitness"])
plt.savefig("mr_high.png", dpi=360)
